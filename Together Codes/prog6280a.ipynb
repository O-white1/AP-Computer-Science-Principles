# %% [markdown]
# ## Prog6280a - Jobs in Data Science

# %% [markdown]
# ## Task 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/workspaces/AP-Computer-Science-Principles/Langdats/jobs_in_data_science.csv')  # no file
df.columns = df.columns.str.strip()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# ...

# %%
avg_salary_by_year = df.groupby('work_year')['salary_in_usd'].mean()
plt.figure(figsize=(10,6))  # 10in x 6in
avg_salary_by_year.plot(kind='line', marker='o')
plt.title('Average Salary in Data Science Over Time')
plt.xlabel('Year')
plt.ylabel('Average Salary (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task 2:

# %%
plt.figure(figsize=(12, 8))
df.head(500).boxplot(column="salary_in_usd",  by="job_title",)
plt.suptitle("")
plt.title("salary_distribution_by_job_title")
plt.xlabel("Job Title")
plt.ylabel("Salary (USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# There is a wide variation in salaries across different job titles, with mostly AI related roles having drastically
# higher median salaries and wider range.

# %% [markdown]
# ## Task 3: Experience Level VS Salary

# %%
salary_by_exp = df.groupby("experience_level")["salary_in_usd"].mean()
#salary_by_exp.plot(kind='bar')
ax = sns.barplot(x=salary_by_exp.index, y=salary_by_exp.values, color = "cyan")
ax.bar_label(ax.containers[0], fontsize=10)

plt.title("Average Salary by Experience level")
plt.xlabel("Experience Level")
plt.ylabel("Average Salary (USD)")
plt.show()

# %% [markdown]
# The average salary increases with experience level, with senior roles typically earning more than mid or entry level positions

# %% [markdown]
# ## Task 4: Geographic Salary distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(y='employee_residence', x='salary_in_usd', data=df.head(2500))

plt.title("Geographic Salary Distribution")
plt.xlabel("Salary (USD)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Salaries in Data Science vary significantly with some like the US having a higher concentration of higher salaries.

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(x="company_size", y="salary_in_usd")

plt.title("Salary Distribution by company Size")
plt.xlabel("Company Size")
plt.ylabel("Salary (USD)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.boxplot(x="company_size", y="salary_in_usd")
#       4 plt.title("Salary Distribution by company Size")
#       5 plt.xlabel("Company Size")
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'y'

# %% [markdown]
# Salaries differ across company sizes, with larger companies usually having a higher salary range.

# %% [markdown]
# ## Task 6: The impact of work setting on salary

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="work_setting", y="salary_in_usd", data=df)

plt.title("Salary VS work setting")
plt.xlabel("Work Setting")
plt.ylabel("Salary (USD)")
plt.show()

# %% [markdown]
# There does not appear to be a clear pattern linking work settings to salary, indicating that other factors contribute more towards the salary than the placement.
